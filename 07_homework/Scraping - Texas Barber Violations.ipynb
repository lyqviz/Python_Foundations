# %% [markdown]
# # Texas Barber Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for barbers in Houson!

# %% [markdown]
# ## Preparation: Knowing your tags
#
# These questions are the same for every data set, and might not work exactly for yours.

# %% [markdown]
# ### What is the tag and class name for every row of data?

# %%
#tr

# %% [markdown]
# ### What is the tag and class name for every person's name?

# %%
#td[0]span[0]

# %% [markdown]
# ### What is the tag and class name for the violation number?

# %%
#td[0]span[-1]

# %% [markdown]
# ### What is the tag and class name for the description of their violation?

# %%
#td[2]

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Try to scrape the page
#
# To test if you requested the page correctly, save the BeautifulSoup document as `doc` and run the code `doc.find_all('tr')[1].text` to get the text of the first `<tr>` element.
#
# - If the result starts with  **nPlease enter at least one (1) parameter** you were NOT successful.
# - If the result starts with **MONTES DE OCA, REINIER**, you were successful.
#
# ### Try to request the page however you think you should.
#
# "Try" to do it, because it *will not work.* Once you've learned that it won't work, you should **ask how to do it on the board**.

# %%
response = requests.post("https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp", data=data)
doc = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### Try to request the page with the correct data parameters
#
# Secret tip: It still won't work. **Ask why not on the board.**

# %%
data = {
    'pht_status':'BAR',
    'pht_lic':'',
    'pht_lnm':'',
    'pht_fnm':'',
    'pht_oth_name':'',
    'phy_city':'HOUSTON',             
    'phy_cnty':'-1',
    'phy_zip':'',
    'B1':'Search',
}

response = requests.post("https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp", data=data)
doc = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### What is the smallest `curl` command that still gives you a result?

# %%
#curl 'https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp' -H 'Referer: https://www.tdlr.texas.gov/cimsfo/' --data 'pht_status=BAR&pht_lic=&pht_lnm=&pht_fnm=&pht_oth_name=&phy_city=HOUSTON+++++++++++++&phy_cnty=-1&phy_zip=&B1=Search'

# %% [markdown]
# ## Request the page with the correct data parameters AND the correct MINIMUM headers
#
# This time it should work.

# %%
data = {
    'pht_status': 'BAR',
    'pht_lic': '',
    'pht_lnm': '',
    'pht_fnm': '',
    'pht_oth_name': '',
    'phy_city': 'HOUSTON',             
    'phy_cnty': '-1',
    'phy_zip': '',
    'B1': 'Search'
}

headers = {
    'Referer': 'https://www.tdlr.texas.gov/cimsfo/'
}

response = requests.post('https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp', data=data, headers=headers)
doc = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ## Scraping

# %% [markdown]
# ### Loop through each `tr` and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen? I'm happy to help if you ask on the board.

# %%
for name in doc.find_all('tr')[1:]:
    print(name.td.span.text.strip())
# Out:
# MONTES DE OCA, REINIER
# ALFORD, RAYMOND
# CHAPMAN, JESSICA
# SALAZAR-ALVAREZ, SAMUEL
# GONZALES, DAVID
# FLORES, CHRISTOPHER
# ARMSTEAD, CEDRIC J
# MORAH, PATRICK
# TREJO, BLADIMAR A
# DAVIS, RICHARD D
# HOPKINS, JOSHUA
# NINO, ROBERT
# HEATH, LOLETHA N
# SALAZAR-ALVAREZ, SAMUEL
# MONTES DE OCA, REINIER
# Company:
# Company:
# SUTTON, EMANUEL B
# SHEPHARD, JAMES C
# HERNANDEZ, MARIA DIOCELINA
# WILLIAMS, DONTUEL
# JOHNSON, JEFFERY J
# Company:
# HUERTA, FRANCISCO
# TIPTON, SELINA I
# ARREOLA, ERIC D
# HARRISON, OTTO M
# RIVERA TORRES, ANGEL D
# PECK, MARVIN
# MOTA SOTO, CRISTIAN D
# WADDLE, EDDIE D
# SON, YOUNG J
# HILL, BRIAN
# BROWN, DELRICK JAREL
# FRANKLIN, KELVIN
# LEDET, LEON
# WILLIAMS, DONTUEL
# LACY, JUSTIN J
# Company:
# ARELLANO, GREGORY F
# MACEDO, ANTONIO
# MILLER, SHAWN ERIC
# HAYWARD, ABBIE DEAN
# BROWN, CHARLES EARL
# MCQUEEN, IDA M
# MCQUEEN, IDA M
# CAESAR, RON
# MORRIS, VICTOR B
# NOLAN, CHRIS B
# BICKHAM, DONNELL
# LOUIS, DIONNE N
# HARRELL, KENTON D
# SUBRAHMANIAN, CHITRA N
# FRANKLIN, LAWRENCE W
# ADAMS, KERRY
# PATTERSON, RONALD
# LANCASTER, MARLANA DEVONE S
# TOLDEN, REGINALD
# SUTTON, DON C
# Company:
# ALLEN, COURTNEY
# BURTON, VICTOR B
# MOTA SOTO, CRISTIAN D
# LLOYD, BRICE
# Company:
# CANDLEY, LARRY
# RUSSELL, HENRY
# AUTHORLEE, LEROY
# SUTTON, DON C
# THOMAS, NAJO T
# DAVIS, RAY LEE
# SCOTT, ALTON C
# STARKS, MICHAEL J
# SHAFFER, TRACY S
# HILLIARD, OLLIE J
# MOTA SOTO, CRISTIAN D
# CARTER, GEORGE I
# Company:
# Company:
# MOSES, DOROTHY A
# ABREU, VICTOR
# TILLMAN, THOMAS A
# JOULEVETTE, CICELY DENISE
# BAUMAN, QUENTIN
# WHITE, TAYSHA
# GARRISON, BRIAN
# CISNEROS, RHINA
# Company:
# HENRY, TONICE M
# FINGER, DAMON C
# BRITE, STEPHEN
# BRITE, STEPHEN
# SPURLING, CINTHIA
# VASQUEZ, JOSE A
# CARTER, GEORGE I
# JACKSON, STEPHON D
# GRAY, TERRY LEE
# SMALLWOOD, ALDON R
# CAESAR, RON
# Company:
# POTTS, MICKEY
# SUBRAHMANIAN, CHITRA N
# HILL, DE MARCUS W
# ANDERSON, ROSE
# TOM, EKERE COLLINS
# MCCUTCHEON, JAMES
# MAU, SREYLY
# PENNIE, DERRICK L
# CORTEZ, LEON
# BOCARD, ALBERT
# Company:
# GUZMAN, WALTER
# Company:
# ROBERSON, EMIEL R
# DEARMAN, ELMER J
# IKEGBUNAM, OSITA H
# SESSION, MARVIN D
# Company:
# POWELL, MARCUS
# MCPHERSON, REGGIE
# FAISON, TIMOTHY
# GARCIA, JULIO CESAR
# CALLUM, LOURAUN
# COLE, RODERICK B
# TORRES, DAVID LEE
# VILLARREAL, EZEQUIEL P
# WOODS, PRINCE L
# REYES, ROBERTO M
# JONES, ALFRED A
# ABOU ELNAGA, ABDALLA
# TENNESSEE, LEO
# PACHECO, ANA C
# GARCIA, MIGUEL A
# WOOTEN, RODNEY J
# JOHNSON, DAVID P
# PETERS, JONATHAN
# BATES, JEMOND D
# CLARK, RONALD B
# WILLIAMS, ANTHONY K
# REYES, ROBERTO M
# VILLARREAL, EZEQUIEL P
# GARCIA, MIGUEL A
# GILBERT, FRANK A
# Company:
# MCQUEEN, IDA M
# Company:
# BANKS, MICHAEL
# MILLER, GEORGE E
# AYALA, FERNANDO E
# HALL, KEVIN
# NATT, ANGELA D
# GUZMAN, DANIEL A
# HAMDANI, AHMED ABDEL Y
# PRICE, WESLEY D
# ABOU ELNAGA, ABDALLA
# DILLARD, NATHANIEL J
# SUTTON, DON C
# GREEN, MERYKA P
# SANCHEZ, OMAR A
# CLAY, DEVIN L
# ALAGOOL, ASAAD KADHIM A
# HAMDANI, AHMED ABDEL Y
# BOYKIN, BRANDON W
# MEDINA, JENIFER
# METOYER, SHAWN M
# PADRON, ESMERALDA
# WILLIAMS, DERRICK D
# RANDALL, ROGER
# COLLINS, ADRIEL MARCUS
# SHAFFER, ANTHONY
# JOULEVETTE, CICELY DENISE
# SEXTON, BYRON E
# PRUITT, ROBERT LEE
# RUSSELL, HENRY
# RAND, CHARLES

# %% [markdown]
# ## Loop through each `tr`, printing each violation description
#
# - TIP: What is the container tag name for it?
# - TIP: You'll get an error even if you're ALMOST right - which row is causing the problem?

# %%
for violation in doc.find_all('tr')[1:]:
    print(violation.find_all('td')[2].text.strip())
# Out:
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent failed to electronically submit to the Department at least one time per month student's accrued hours.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent performed barbering without the required license.
# Respondent practiced barbering in an unlicensed facility.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to cooperate with an inspection.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to cooperate with an inspection; Respondent operated a barbershop with an expired license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent is ordered to immediately cease and desist from acting as or impersonating a licensed barber and/or performing or offering to provide barbering services for customers, clients, or the public.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a cosmetology salon with an expired license.
# Respondent operated a barbershop with an expired license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent practiced barbering in an unlicensed facility.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Applicant has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.
# Respondent operated a barbershop with an expired license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent failed to report student hours electronically to the Department at least once per month.
# Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent failed to report student hours electronically to the Department at least once per month.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.
# Respondent operated a barbershop without holding the appropriate license.
# Respondent performed barbering with an expired license.
# Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Applicant has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation; Applicant has been convicted of a crime that was committed within 5 years of his application.
# Respondent failed to properly clean and disinfect hair cutting, styling and treatment equipment, implements, tools and materials; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent performed barbering without the required license.
# Respondent failed to provide a student who had enrolled in school a copy of the refund policy.
# Respondent performed barbering with an expired license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent left applicators standing in the wax. Respondent failed to apply for a new salon license within thirty (30) days of a change of ownership.
# Respondent performed barbering with an expired license.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to submit a student's accrued hours once per month; Respondent failed to make available for Department review monthly progress reports and daily attendance records for a student.
# Respondent practiced barbering in an unlicensed facility.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent performed barbering without the required license.
# Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.
# Respondent is assessed an administrative penalty in the amount of $
# Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent allowed a student on the premises who was not wearing a smock.
# Respondent performed barbering without the required license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent failed to have a container of liquid disinfectant at each barber station; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent performed barbering without the required license.
# Applicant lacks sufficient honesty, trustworthiness and integrity to hold a license; Applicant has been convicted of a crime that was committed within 5 years of his application.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent performed barbering with an expired license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed of a barber establishment owner, manager, or their representative to cooperate with an inspector in the performance of the inspection.
# Respondent failed to properly account for hours granted to each student.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# Respondent failed to obtain a new permit within 30 days following the transfer of ownership; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to obtain a new permit within 30 days following the transfer of ownership; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a barbershop with an expired license; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent possessed or used of fumigants such as formalin (formaldehyde) tablets or liquids.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent leased space in a barber shop to multiple individuals who engaged in the practice of barbering but had not obtained a barber license; Respondent operated a barbershop without holding the appropriate license; Respondent failed to have a container of liquid disinfectant located at each barber chair or station; Respondent's hand washing facilities failed to include hot and cold running water.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent practiced barbering in an unlicensed facility.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent decreased hours earned by students in their school records.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent operated a barbershop with an expired license.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a barbershop without holding the appropriate license.
# Respondent practiced barbering in an unlicensed facility.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondents failed to obtain a new license after the shop moved.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent left applicators standing in the wax.
# Respondent performed barbering without the required license.
# Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation; Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history.
# Respondent operated a barbershop without holding the appropriate license; Respondent performed barbering without the required license.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to have a container of liquid disinfectant located at each barber chair or station; Respondent failed to disinfect shampoo bowls and manicure tables prior to use for each client.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent failed to comply with an order previously issued by the Executive Director; Respondent performed barbering with an expired license.
# Respondent operated a barbershop without holding the appropriate license.
# Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# Respondent operated a barbershop with an expired license; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.
# Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to multiple individuals who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to submit to the Department an electronic record of each student's accrued hours; Respondent increased credit hours earned to multiple students.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent failed to have hand washing facility with hot running water.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# Respondent performed barbering with an expired license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Applicant lacks sufficient honesty, trustworthiness and integrity to hold a license; Applicant has been convicted of a crime that was committed within 5 years of his application.
# Respondent performed barbering with an expired license.
# Respondent operated a barbershop without holding the appropriate license; Respondent performed barbering without the required license.

# %% [markdown]
# ## Loop through each `tr`, printing the complaint number
#
# - TIP: It should be the last piece of the fist `td`

# %%
for number in doc.find_all('tr')[1:]:
    print(number.td.find_all('span')[-1].text.strip())
# Out:
# BAR20170009735
# BAR20170013061
# BAR20160014463
# BAR20170009706
# BAR20160024898
# BAR20170003858
# BAR20170017750
# BAR20170001067
# BAR20170015712
# BAR20160026976
# BAR20170004945
# BAR20170005752
# BAR20170008862
# BAR20170009706
# BAR20170009735
# BAR20170010211
# BAR20170015711
# BAR20170005607
# BAR20170012408
# BAR20160015455
# BAR20170004000
# BAR20170004622
# BAR20170009953
# BAR20160019178
# BAR20170003998
# BAR20170005585
# BAR20170004247
# BAR20170004644
# BAR20170001084
# BAR20170003233
# BAR20170007267
# BAR20170004607
# BAR20170004726
# BAR20170000258
# BAR20170000872
# BAR20170000888
# BAR20170004000
# BAR20170001296
# BAR20170001765
# BAR20160000930
# BAR20160012081
# BAR20160023793
# BAR20160020239
# BAR20160025221
# BAR20160003560
# BAR20160014501
# BAR20160020292
# BAR20160019711
# BAR20160020884
# BAR20160013209
# BAR20160013204
# BAR20160013487
# BAR20160020715
# BAR20150023440
# BAR20160015167
# BAR20160010384
# BAR20160010595
# BAR20160010403
# BAR20160003712
# BAR20160002891
# BAR20160006458
# BAR20160017201
# BAR20160005691
# BAR20160012167
# BAR20160010137
# BAR20150016373
# BAR20150020574
# BAR20160011498
# BAR20150022763
# BAR20150024251
# BAR20150014628
# BAR20150016869
# BAR20150005142
# BAR20160000710
# BAR20160003580
# BAR20150020772
# BAR20150022808
# BAR20150012542
# BAR20150020936
# BAR20160006057
# BAR20150020900
# BAR20140020322
# BAR20150023686
# BAR20160002257
# BAR20160006283
# BAR20150015351
# BAR20150017189
# BAR20160003552
# BAR20150016865
# BAR20150003948
# BAR20140012731
# BAR20150015995
# BAR20140013044
# BAR20150021856
# BAR20150022808
# BAR20160001941
# BAR20150015119
# BAR20150020299
# BAR20140019723
# BAR20150020936
# BAR20150020943
# BAR20150008887
# BAR20150010286
# BAR20150015346
# BAR20150008529
# BAR20150020726
# BAR20150011280
# BAR20150014646
# BAR20150016885
# BAR20150012508
# BAR20140004827
# BAR20150007016
# BAR20150009370
# BAR20150004210
# BAR20150013309
# BAR20140001295
# BAR20140020206
# BAR20150012542
# BAR20150012580
# BAR20140008929
# BAR20150014662
# BAR20140016309
# BAR20150013794
# BAR20150013147
# BAR20150009264
# BAR20140005542
# BAR20150003439
# BAR20140005541
# BAR20150003945
# BAR20150006308
# BAR20150010343
# BAR20150007310
# BAR20140005543
# BAR20140011649
# BAR20140001139
# BAR20140019446
# BAR20150009491
# BAR20150001429
# BAR20150008390
# BAR20140005541
# BAR20140005542
# BAR20140005543
# BAR20140008927
# BAR20140017760
# BAR20140002728
# BAR20150003987
# BAR20120020318
# BAR20150006331
# BAR20150007314
# BAR20150004544
# BAR20130015774
# BAR20140014935
# BAR20150002030
# BAR20150005628
# BAR20150002028
# BAR20150003768
# BAR20140018349
# BAR20150000367
# BAR20130018669
# BAR20150002894
# BAR20150002029
# BAR20150002030
# BAR20140006139
# BAR20140016318
# BAR20140017873
# BAR20140017648
# BAR20140019563
# BAR20140006135
# BAR20140007767
# BAR20130019444
# BAR20140001969
# BAR20140017962
# BAR20140010225
# BAR20120016389
# BAR20130014676

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
#
# Create a new dictionary for each `tr` (except the header).

# %%
Violations = []

for violation in doc.find_all('tr')[1:]:
    Violations.append({
        'name': violation.td.span.text.strip(),
        'Violation_description': violation.find_all('td')[2].text.strip(),
        'Violation_number': violation.td.find_all('span')[-1].text.strip()
    })

Violations
# Out:
# [{'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170009735',
#   'name': 'MONTES DE OCA, REINIER'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170013061',
#   'name': 'ALFORD, RAYMOND'},
#  {'Violation_description': "Respondent failed to electronically submit to the Department at least one time per month student's accrued hours.",
#   'Violation_number': 'BAR20160014463',
#   'name': 'CHAPMAN, JESSICA'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170009706',
#   'name': 'SALAZAR-ALVAREZ, SAMUEL'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20160024898',
#   'name': 'GONZALES, DAVID'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20170003858',
#   'name': 'FLORES, CHRISTOPHER'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20170017750',
#   'name': 'ARMSTEAD, CEDRIC J'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'Violation_number': 'BAR20170001067',
#   'name': 'MORAH, PATRICK'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170015712',
#   'name': 'TREJO, BLADIMAR A'},
#  {'Violation_description': 'Respondent practiced barbering in an unlicensed facility.',
#   'Violation_number': 'BAR20160026976',
#   'name': 'DAVIS, RICHARD D'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170004945',
#   'name': 'HOPKINS, JOSHUA'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170005752',
#   'name': 'NINO, ROBERT'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'Violation_number': 'BAR20170008862',
#   'name': 'HEATH, LOLETHA N'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170009706',
#   'name': 'SALAZAR-ALVAREZ, SAMUEL'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170009735',
#   'name': 'MONTES DE OCA, REINIER'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170010211',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170015711',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170005607',
#   'name': 'SUTTON, EMANUEL B'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20170012408',
#   'name': 'SHEPHARD, JAMES C'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to cooperate with an inspection.',
#   'Violation_number': 'BAR20160015455',
#   'name': 'HERNANDEZ, MARIA DIOCELINA'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170004000',
#   'name': 'WILLIAMS, DONTUEL'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170004622',
#   'name': 'JOHNSON, JEFFERY J'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170009953',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to cooperate with an inspection; Respondent operated a barbershop with an expired license.',
#   'Violation_number': 'BAR20160019178',
#   'name': 'HUERTA, FRANCISCO'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20170003998',
#   'name': 'TIPTON, SELINA I'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20170005585',
#   'name': 'ARREOLA, ERIC D'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170004247',
#   'name': 'HARRISON, OTTO M'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170004644',
#   'name': 'RIVERA TORRES, ANGEL D'},
#  {'Violation_description': 'Respondent is ordered to immediately cease and desist from acting as or impersonating a licensed barber and/or performing or offering to provide barbering services for customers, clients, or the public.',
#   'Violation_number': 'BAR20170001084',
#   'name': 'PECK, MARVIN'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20170003233',
#   'name': 'MOTA SOTO, CRISTIAN D'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20170007267',
#   'name': 'WADDLE, EDDIE D'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'Violation_number': 'BAR20170004607',
#   'name': 'SON, YOUNG J'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20170004726',
#   'name': 'HILL, BRIAN'},
#  {'Violation_description': 'Respondent operated a cosmetology salon with an expired license.',
#   'Violation_number': 'BAR20170000258',
#   'name': 'BROWN, DELRICK JAREL'},
#  {'Violation_description': 'Respondent operated a barbershop with an expired license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'Violation_number': 'BAR20170000872',
#   'name': 'FRANKLIN, KELVIN'},
#  {'Violation_description': 'Respondent practiced barbering in an unlicensed facility.',
#   'Violation_number': 'BAR20170000888',
#   'name': 'LEDET, LEON'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20170004000',
#   'name': 'WILLIAMS, DONTUEL'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20170001296',
#   'name': 'LACY, JUSTIN J'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20170001765',
#   'name': 'Company:'},
#  {'Violation_description': 'Applicant has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.',
#   'Violation_number': 'BAR20160000930',
#   'name': 'ARELLANO, GREGORY F'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20160012081',
#   'name': 'MACEDO, ANTONIO'},
#  {'Violation_description': 'Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.',
#   'Violation_number': 'BAR20160023793',
#   'name': 'MILLER, SHAWN ERIC'},
#  {'Violation_description': 'Respondent operated a barbershop with an expired license.',
#   'Violation_number': 'BAR20160020239',
#   'name': 'HAYWARD, ABBIE DEAN'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20160025221',
#   'name': 'BROWN, CHARLES EARL'},
#  {'Violation_description': "Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent failed to report student hours electronically to the Department at least once per month.",
#   'Violation_number': 'BAR20160003560',
#   'name': 'MCQUEEN, IDA M'},
#  {'Violation_description': "Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent failed to report student hours electronically to the Department at least once per month.",
#   'Violation_number': 'BAR20160014501',
#   'name': 'MCQUEEN, IDA M'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20160020292',
#   'name': 'CAESAR, RON'},
#  {'Violation_description': 'Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.',
#   'Violation_number': 'BAR20160019711',
#   'name': 'MORRIS, VICTOR B'},
#  {'Violation_description': 'Respondent operated a barbershop without holding the appropriate license.',
#   'Violation_number': 'BAR20160020884',
#   'name': 'NOLAN, CHRIS B'},
#  {'Violation_description': 'Respondent performed barbering with an expired license.',
#   'Violation_number': 'BAR20160013209',
#   'name': 'BICKHAM, DONNELL'},
#  {'Violation_description': 'Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'Violation_number': 'BAR20160013204',
#   'name': 'LOUIS, DIONNE N'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'Violation_number': 'BAR20160013487',
#   'name': 'HARRELL, KENTON D'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20160020715',
#   'name': 'SUBRAHMANIAN, CHITRA N'},
#  {'Violation_description': 'Applicant has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation; Applicant has been convicted of a crime that was committed within 5 years of his application.',
#   'Violation_number': 'BAR20150023440',
#   'name': 'FRANKLIN, LAWRENCE W'},
#  {'Violation_description': 'Respondent failed to properly clean and disinfect hair cutting, styling and treatment equipment, implements, tools and materials; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.',
#   'Violation_number': 'BAR20160015167',
#   'name': 'ADAMS, KERRY'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20160010384',
#   'name': 'PATTERSON, RONALD'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20160010595',
#   'name': 'LANCASTER, MARLANA DEVONE S'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20160010403',
#   'name': 'TOLDEN, REGINALD'},
#  {'Violation_description': 'Respondent failed to provide a student who had enrolled in school a copy of the refund policy.',
#   'Violation_number': 'BAR20160003712',
#   'name': 'SUTTON, DON C'},
#  {'Violation_description': 'Respondent performed barbering with an expired license.',
#   'Violation_number': 'BAR20160002891',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20160006458',
#   'name': 'ALLEN, COURTNEY'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20160017201',
#   'name': 'BURTON, VICTOR B'},
#  {'Violation_description': 'Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20160005691',
#   'name': 'MOTA SOTO, CRISTIAN D'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20160012167',
#   'name': 'LLOYD, BRICE'},
#  {'Violation_description': 'Respondent left applicators standing in the wax. Respondent failed to apply for a new salon license within thirty (30) days of a change of ownership.',
#   'Violation_number': 'BAR20160010137',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent performed barbering with an expired license.',
#   'Violation_number': 'BAR20150016373',
#   'name': 'CANDLEY, LARRY'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20150020574',
#   'name': 'RUSSELL, HENRY'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20160011498',
#   'name': 'AUTHORLEE, LEROY'},
#  {'Violation_description': "Respondent failed to submit a student's accrued hours once per month; Respondent failed to make available for Department review monthly progress reports and daily attendance records for a student.",
#   'Violation_number': 'BAR20150022763',
#   'name': 'SUTTON, DON C'},
#  {'Violation_description': 'Respondent practiced barbering in an unlicensed facility.',
#   'Violation_number': 'BAR20150024251',
#   'name': 'THOMAS, NAJO T'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'Violation_number': 'BAR20150014628',
#   'name': 'DAVIS, RAY LEE'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150016869',
#   'name': 'SCOTT, ALTON C'},
#  {'Violation_description': 'Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.',
#   'Violation_number': 'BAR20150005142',
#   'name': 'STARKS, MICHAEL J'},
#  {'Violation_description': 'Respondent is assessed an administrative penalty in the amount of $',
#   'Violation_number': 'BAR20160000710',
#   'name': 'SHAFFER, TRACY S'},
#  {'Violation_description': "Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent allowed a student on the premises who was not wearing a smock.",
#   'Violation_number': 'BAR20160003580',
#   'name': 'HILLIARD, OLLIE J'},
#  {'Violation_description': 'Respondent performed barbering without the required license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'Violation_number': 'BAR20150020772',
#   'name': 'MOTA SOTO, CRISTIAN D'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150022808',
#   'name': 'CARTER, GEORGE I'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150012542',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150020936',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent failed to have a container of liquid disinfectant at each barber station; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'Violation_number': 'BAR20160006057',
#   'name': 'MOSES, DOROTHY A'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150020900',
#   'name': 'ABREU, VICTOR'},
#  {'Violation_description': 'Applicant lacks sufficient honesty, trustworthiness and integrity to hold a license; Applicant has been convicted of a crime that was committed within 5 years of his application.',
#   'Violation_number': 'BAR20140020322',
#   'name': 'TILLMAN, THOMAS A'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20150023686',
#   'name': 'JOULEVETTE, CICELY DENISE'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20160002257',
#   'name': 'BAUMAN, QUENTIN'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20160006283',
#   'name': 'WHITE, TAYSHA'},
#  {'Violation_description': 'Respondent performed barbering with an expired license.',
#   'Violation_number': 'BAR20150015351',
#   'name': 'GARRISON, BRIAN'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed of a barber establishment owner, manager, or their representative to cooperate with an inspector in the performance of the inspection.',
#   'Violation_number': 'BAR20150017189',
#   'name': 'CISNEROS, RHINA'},
#  {'Violation_description': 'Respondent failed to properly account for hours granted to each student.',
#   'Violation_number': 'BAR20160003552',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20150016865',
#   'name': 'HENRY, TONICE M'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150003948',
#   'name': 'FINGER, DAMON C'},
#  {'Violation_description': 'Respondent failed to obtain a new permit within 30 days following the transfer of ownership; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'Violation_number': 'BAR20140012731',
#   'name': 'BRITE, STEPHEN'},
#  {'Violation_description': 'Respondent failed to obtain a new permit within 30 days following the transfer of ownership; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'Violation_number': 'BAR20150015995',
#   'name': 'BRITE, STEPHEN'},
#  {'Violation_description': 'Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.',
#   'Violation_number': 'BAR20140013044',
#   'name': 'SPURLING, CINTHIA'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20150021856',
#   'name': 'VASQUEZ, JOSE A'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150022808',
#   'name': 'CARTER, GEORGE I'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20160001941',
#   'name': 'JACKSON, STEPHON D'},
#  {'Violation_description': 'Respondent operated a barbershop with an expired license; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'Violation_number': 'BAR20150015119',
#   'name': 'GRAY, TERRY LEE'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150020299',
#   'name': 'SMALLWOOD, ALDON R'},
#  {'Violation_description': 'Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20140019723',
#   'name': 'CAESAR, RON'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150020936',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150020943',
#   'name': 'POTTS, MICKEY'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20150008887',
#   'name': 'SUBRAHMANIAN, CHITRA N'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'Violation_number': 'BAR20150010286',
#   'name': 'HILL, DE MARCUS W'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'Violation_number': 'BAR20150015346',
#   'name': 'ANDERSON, ROSE'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20150008529',
#   'name': 'TOM, EKERE COLLINS'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150020726',
#   'name': 'MCCUTCHEON, JAMES'},
#  {'Violation_description': 'Respondent possessed or used of fumigants such as formalin (formaldehyde) tablets or liquids.',
#   'Violation_number': 'BAR20150011280',
#   'name': 'MAU, SREYLY'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'Violation_number': 'BAR20150014646',
#   'name': 'PENNIE, DERRICK L'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150016885',
#   'name': 'CORTEZ, LEON'},
#  {'Violation_description': 'Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'Violation_number': 'BAR20150012508',
#   'name': 'BOCARD, ALBERT'},
#  {'Violation_description': "Respondent leased space in a barber shop to multiple individuals who engaged in the practice of barbering but had not obtained a barber license; Respondent operated a barbershop without holding the appropriate license; Respondent failed to have a container of liquid disinfectant located at each barber chair or station; Respondent's hand washing facilities failed to include hot and cold running water.",
#   'Violation_number': 'BAR20140004827',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20150007016',
#   'name': 'GUZMAN, WALTER'},
#  {'Violation_description': 'Respondent practiced barbering in an unlicensed facility.',
#   'Violation_number': 'BAR20150009370',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20150004210',
#   'name': 'ROBERSON, EMIEL R'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150013309',
#   'name': 'DEARMAN, ELMER J'},
#  {'Violation_description': 'Respondent decreased hours earned by students in their school records.',
#   'Violation_number': 'BAR20140001295',
#   'name': 'IKEGBUNAM, OSITA H'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent operated a barbershop with an expired license.',
#   'Violation_number': 'BAR20140020206',
#   'name': 'SESSION, MARVIN D'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150012542',
#   'name': 'Company:'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150012580',
#   'name': 'POWELL, MARCUS'},
#  {'Violation_description': 'Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.',
#   'Violation_number': 'BAR20140008929',
#   'name': 'MCPHERSON, REGGIE'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150014662',
#   'name': 'FAISON, TIMOTHY'},
#  {'Violation_description': 'Respondent operated a barbershop without holding the appropriate license.',
#   'Violation_number': 'BAR20140016309',
#   'name': 'GARCIA, JULIO CESAR'},
#  {'Violation_description': 'Respondent practiced barbering in an unlicensed facility.',
#   'Violation_number': 'BAR20150013794',
#   'name': 'CALLUM, LOURAUN'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150013147',
#   'name': 'COLE, RODERICK B'},
#  {'Violation_description': 'Respondents failed to obtain a new license after the shop moved.',
#   'Violation_number': 'BAR20150009264',
#   'name': 'TORRES, DAVID LEE'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20140005542',
#   'name': 'VILLARREAL, EZEQUIEL P'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'Violation_number': 'BAR20150003439',
#   'name': 'WOODS, PRINCE L'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20140005541',
#   'name': 'REYES, ROBERTO M'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.',
#   'Violation_number': 'BAR20150003945',
#   'name': 'JONES, ALFRED A'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20150006308',
#   'name': 'ABOU ELNAGA, ABDALLA'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150010343',
#   'name': 'TENNESSEE, LEO'},
#  {'Violation_description': 'Respondent left applicators standing in the wax.',
#   'Violation_number': 'BAR20150007310',
#   'name': 'PACHECO, ANA C'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20140005543',
#   'name': 'GARCIA, MIGUEL A'},
#  {'Violation_description': "Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation; Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history.",
#   'Violation_number': 'BAR20140011649',
#   'name': 'WOOTEN, RODNEY J'},
#  {'Violation_description': 'Respondent operated a barbershop without holding the appropriate license; Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20140001139',
#   'name': 'JOHNSON, DAVID P'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20140019446',
#   'name': 'PETERS, JONATHAN'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150009491',
#   'name': 'BATES, JEMOND D'},
#  {'Violation_description': 'Respondent failed to have a container of liquid disinfectant located at each barber chair or station; Respondent failed to disinfect shampoo bowls and manicure tables prior to use for each client.',
#   'Violation_number': 'BAR20150001429',
#   'name': 'CLARK, RONALD B'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150008390',
#   'name': 'WILLIAMS, ANTHONY K'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20140005541',
#   'name': 'REYES, ROBERTO M'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20140005542',
#   'name': 'VILLARREAL, EZEQUIEL P'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20140005543',
#   'name': 'GARCIA, MIGUEL A'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director; Respondent performed barbering with an expired license.',
#   'Violation_number': 'BAR20140008927',
#   'name': 'GILBERT, FRANK A'},
#  {'Violation_description': 'Respondent operated a barbershop without holding the appropriate license.',
#   'Violation_number': 'BAR20140017760',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.',
#   'Violation_number': 'BAR20140002728',
#   'name': 'MCQUEEN, IDA M'},
#  {'Violation_description': 'Respondent operated a barbershop with an expired license; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'Violation_number': 'BAR20150003987',
#   'name': 'Company:'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20120020318',
#   'name': 'BANKS, MICHAEL'},
#  {'Violation_description': 'Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.',
#   'Violation_number': 'BAR20150006331',
#   'name': 'MILLER, GEORGE E'},
#  {'Violation_description': 'Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.',
#   'Violation_number': 'BAR20150007314',
#   'name': 'AYALA, FERNANDO E'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150004544',
#   'name': 'HALL, KEVIN'},
#  {'Violation_description': 'Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.',
#   'Violation_number': 'BAR20130015774',
#   'name': 'NATT, ANGELA D'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20140014935',
#   'name': 'GUZMAN, DANIEL A'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150002030',
#   'name': 'HAMDANI, AHMED ABDEL Y'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150005628',
#   'name': 'PRICE, WESLEY D'},
#  {'Violation_description': 'Respondent leased space in a barber shop to multiple individuals who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20150002028',
#   'name': 'ABOU ELNAGA, ABDALLA'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150003768',
#   'name': 'DILLARD, NATHANIEL J'},
#  {'Violation_description': "Respondent failed to submit to the Department an electronic record of each student's accrued hours; Respondent increased credit hours earned to multiple students.",
#   'Violation_number': 'BAR20140018349',
#   'name': 'SUTTON, DON C'},
#  {'Violation_description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'Violation_number': 'BAR20150000367',
#   'name': 'GREEN, MERYKA P'},
#  {'Violation_description': 'Respondent failed to have hand washing facility with hot running water.',
#   'Violation_number': 'BAR20130018669',
#   'name': 'SANCHEZ, OMAR A'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20150002894',
#   'name': 'CLAY, DEVIN L'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150002029',
#   'name': 'ALAGOOL, ASAAD KADHIM A'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20150002030',
#   'name': 'HAMDANI, AHMED ABDEL Y'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20140006139',
#   'name': 'BOYKIN, BRANDON W'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20140016318',
#   'name': 'MEDINA, JENIFER'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20140017873',
#   'name': 'METOYER, SHAWN M'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20140017648',
#   'name': 'PADRON, ESMERALDA'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20140019563',
#   'name': 'WILLIAMS, DERRICK D'},
#  {'Violation_description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20140006135',
#   'name': 'RANDALL, ROGER'},
#  {'Violation_description': 'Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'Violation_number': 'BAR20140007767',
#   'name': 'COLLINS, ADRIEL MARCUS'},
#  {'Violation_description': 'Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20130019444',
#   'name': 'SHAFFER, ANTHONY'},
#  {'Violation_description': 'Respondent performed barbering with an expired license.',
#   'Violation_number': 'BAR20140001969',
#   'name': 'JOULEVETTE, CICELY DENISE'},
#  {'Violation_description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'Violation_number': 'BAR20140017962',
#   'name': 'SEXTON, BYRON E'},
#  {'Violation_description': 'Applicant lacks sufficient honesty, trustworthiness and integrity to hold a license; Applicant has been convicted of a crime that was committed within 5 years of his application.',
#   'Violation_number': 'BAR20140010225',
#   'name': 'PRUITT, ROBERT LEE'},
#  {'Violation_description': 'Respondent performed barbering with an expired license.',
#   'Violation_number': 'BAR20120016389',
#   'name': 'RUSSELL, HENRY'},
#  {'Violation_description': 'Respondent operated a barbershop without holding the appropriate license; Respondent performed barbering without the required license.',
#   'Violation_number': 'BAR20130014676',
#   'name': 'RAND, CHARLES'}]

# %% [markdown]
# ### Save that to a CSV

# %%
import pandas as pd
df = pd.DataFrame(Violations)
df.to_csv('Violations.csv', index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
pd.read_csv('Violations.csv')
# Out:
#                                  Violation_description Violation_number  \
# 0    Respondent performed barbering without the req...   BAR20170009735
# 1    Respondent performed barbering without the req...   BAR20170013061
# 2    Respondent failed to electronically submit to ...   BAR20160014463
# 3    Respondent performed barbering without the req...   BAR20170009706
# 4    Respondent leased space in a barber shop to an...   BAR20160024898
# 5    Respondent leased space in a barber shop to an...   BAR20170003858
# 6    The Respondent's license was revoked upon Resp...   BAR20170017750
# 7    Respondent leased space in a barber shop to an...   BAR20170001067
# 8    Respondent performed barbering without the req...   BAR20170015712
# 9    Respondent practiced barbering in an unlicense...   BAR20160026976
# 10   Respondent performed barbering without the req...   BAR20170004945
# 11   Respondent performed barbering without the req...   BAR20170005752
# 12   Respondent leased space in a barber shop to an...   BAR20170008862
# 13   Respondent performed barbering without the req...   BAR20170009706
# 14   Respondent performed barbering without the req...   BAR20170009735
# 15   Respondent performed barbering without the req...   BAR20170010211
# 16   Respondent performed barbering without the req...   BAR20170015711
# 17   Respondent performed barbering without the req...   BAR20170005607
# 18   The Respondent's license was revoked upon Resp...   BAR20170012408
# 19   Respondent leased space in a barber shop to an...   BAR20160015455
# 20   Respondent performed barbering without the req...   BAR20170004000
# 21   Respondent performed barbering without the req...   BAR20170004622
# 22   Respondent performed barbering without the req...   BAR20170009953
# 23   Respondent leased space in a barber shop to an...   BAR20160019178
# 24   Respondent leased space in a barber shop to an...   BAR20170003998
# 25   Respondent leased space in a barber shop to an...   BAR20170005585
# 26   Respondent performed barbering without the req...   BAR20170004247
# 27   Respondent performed barbering without the req...   BAR20170004644
# 28   Respondent is ordered to immediately cease and...   BAR20170001084
# 29   Respondent failed to comply with an order prev...   BAR20170003233
# ..                                                 ...              ...
# 145  Respondent operated a barbershop with an expir...   BAR20150003987
# 146  Respondent failed to comply with an order prev...   BAR20120020318
# 147  Respondent failed to prepare fresh disinfectan...   BAR20150006331
# 148  Respondent failed to prepare fresh disinfectan...   BAR20150007314
# 149  The Respondent's license was revoked upon Resp...   BAR20150004544
# 150  Respondent failed to clean required implements...   BAR20130015774
# 151  Respondent failed to comply with an order prev...   BAR20140014935
# 152  Respondent performed barbering without the req...   BAR20150002030
# 153  The Respondent's license was revoked upon Resp...   BAR20150005628
# 154  Respondent leased space in a barber shop to mu...   BAR20150002028
# 155  The Respondent's license was revoked upon Resp...   BAR20150003768
# 156  Respondent failed to submit to the Department ...   BAR20140018349
# 157  Respondent failed to comply with an order prev...   BAR20150000367
# 158  Respondent failed to have hand washing facilit...   BAR20130018669
# 159  The Respondent's license was revoked upon Resp...   BAR20150002894
# 160  Respondent performed barbering without the req...   BAR20150002029
# 161  Respondent performed barbering without the req...   BAR20150002030
# 162  Respondent performed barbering without the req...   BAR20140006139
# 163  Respondent leased space in a barber shop to an...   BAR20140016318
# 164  The Respondent's license was revoked upon Resp...   BAR20140017873
# 165  Respondent leased space in a barber shop to an...   BAR20140017648
# 166  The Respondent's license was revoked upon Resp...   BAR20140019563
# 167  Respondent leased space in a barber shop to an...   BAR20140006135
# 168  Respondent operated a barbershop with an expir...   BAR20140007767
# 169  Respondent performed barbering without the req...   BAR20130019444
# 170  Respondent performed barbering with an expired...   BAR20140001969
# 171  The Respondent's license was revoked upon Resp...   BAR20140017962
# 172  Applicant lacks sufficient honesty, trustworth...   BAR20140010225
# 173  Respondent performed barbering with an expired...   BAR20120016389
# 174  Respondent operated a barbershop without holdi...   BAR20130014676
#
#                            name
# 0        MONTES DE OCA, REINIER
# 1               ALFORD, RAYMOND
# 2              CHAPMAN, JESSICA
# 3       SALAZAR-ALVAREZ, SAMUEL
# 4               GONZALES, DAVID
# 5           FLORES, CHRISTOPHER
# 6            ARMSTEAD, CEDRIC J
# 7                MORAH, PATRICK
# 8             TREJO, BLADIMAR A
# 9              DAVIS, RICHARD D
# 10              HOPKINS, JOSHUA
# 11                 NINO, ROBERT
# 12             HEATH, LOLETHA N
# 13      SALAZAR-ALVAREZ, SAMUEL
# 14       MONTES DE OCA, REINIER
# 15                     Company:
# 16                     Company:
# 17            SUTTON, EMANUEL B
# 18            SHEPHARD, JAMES C
# 19   HERNANDEZ, MARIA DIOCELINA
# 20            WILLIAMS, DONTUEL
# 21           JOHNSON, JEFFERY J
# 22                     Company:
# 23            HUERTA, FRANCISCO
# 24             TIPTON, SELINA I
# 25              ARREOLA, ERIC D
# 26             HARRISON, OTTO M
# 27       RIVERA TORRES, ANGEL D
# 28                 PECK, MARVIN
# 29        MOTA SOTO, CRISTIAN D
# ..                          ...
# 145                    Company:
# 146              BANKS, MICHAEL
# 147            MILLER, GEORGE E
# 148           AYALA, FERNANDO E
# 149                 HALL, KEVIN
# 150              NATT, ANGELA D
# 151            GUZMAN, DANIEL A
# 152      HAMDANI, AHMED ABDEL Y
# 153             PRICE, WESLEY D
# 154        ABOU ELNAGA, ABDALLA
# 155        DILLARD, NATHANIEL J
# 156               SUTTON, DON C
# 157             GREEN, MERYKA P
# 158             SANCHEZ, OMAR A
# 159               CLAY, DEVIN L
# 160     ALAGOOL, ASAAD KADHIM A
# 161      HAMDANI, AHMED ABDEL Y
# 162           BOYKIN, BRANDON W
# 163             MEDINA, JENIFER
# 164            METOYER, SHAWN M
# 165           PADRON, ESMERALDA
# 166         WILLIAMS, DERRICK D
# 167              RANDALL, ROGER
# 168      COLLINS, ADRIEL MARCUS
# 169            SHAFFER, ANTHONY
# 170   JOULEVETTE, CICELY DENISE
# 171             SEXTON, BYRON E
# 172          PRUITT, ROBERT LEE
# 173              RUSSELL, HENRY
# 174               RAND, CHARLES
#
# [175 rows x 3 columns]
