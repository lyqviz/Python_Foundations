# %% [markdown]
# # Exercise: Cherry Blossoms!
#
# #### Summary
#
# Once upon a time it was サクラ season, which meant the [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were in full bloom! This year they bloomed a little early and they've long sinced faded, so for today we'll stick with data-driven blossoms: http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/
#
# #### Data Source(s)
#
# Historical Series of Phenological data for Cherry Tree Flowering at Kyoto City
# (and March Mean Temperature Reconstructions), http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/
#
# #### Files
#
# - KyotoFullFlower7.xls, "Full-flowering Dates of Prunus jamasakura in Kyoto City"
#
# #### Skills
#
# - Working with Excel files
# - Ignoring the first few rows
# - Replacing NaN values
# - Counting and summarizing columns
# - Replacing non-NaN values
# - Extracting with strings
# - Rolling means

# %% [markdown]
# # Read in `KyotoFullFlower7.xls`
#
# Be sure to look at the first five rows.

# %%
import pandas as pd

# %%
df = pd.read_excel('KyotoFullFlower7.xls')

# %%
df.head()
# Out:
#   Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0  This phenological data was acquired by followi...
# 1                                                NaN
# 2                                     Column A; A.D.
# 3       Column B; Full-flowering date (day of year).
# 4  Column C; Full-flowering date (calender date, ...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# ### That... doesn't look right. Why not?
#
# Examine your column names, and maybe even open up the file in Excel.

# %% [markdown]
# ### Read in the file correctly, and look at the first five rows
#
# - TIP: The first year should be 801 AD, and it should not have any dates or anything.

# %%
df = pd.read_excel('KyotoFullFlower7.xls', skiprows=25)
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN              -
# 1             NaN              -
# 2             NaN              -
# 3             NaN              -
# 4             NaN              -

# %% [markdown]
# ### Look at the final five rows of the data

# %%
df.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## Watching out for NaN values

# %% [markdown]
# Take a look at **Reference name**. Is there something you should set to be `NaN`? Use either of the two ways we have covered.

# %%
import numpy as np
df['Reference Name'].replace('-', np.nan, inplace=True)

# %%
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %% [markdown]
# ### Check that you have 827 values for "Full-flowering date (DOY)" and 825 for "Reference Name"

# %%
df['Full-flowering date (DOY)'].describe()
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: Full-flowering date (DOY), dtype: float64

# %%
df['Reference Name'].describe()
# Out:
# count                        825
# unique                       222
# top       NEWS-PAPER(ARASHIYAMA)
# freq                          94
# Name: Reference Name, dtype: object

# %% [markdown]
# # Cleaning up our data

# %% [markdown]
# ## What sources are the most common as a reference?

# %%
df['Reference Name'].value_counts()
# Out:
# NEWS-PAPER(ARASHIYAMA)              94
# SUGIURAKE-NIKKI                     38
# MYOHOIN-HINAMIKI                    32
# OYUDONONO-UENO-NIKKI                26
# DAIGOJI-ZATSUYO                     21
# OYUDONONO-UENO-NIKKI [EDA]          21
# NIHONKIRYAKU                        19
# SANETAKA-KOKI                       19
# (SHIRYO-SORAN)                      15
# KAKUMEIKI                           15
# ZOKU-SHIGUSHO                       14
# NISUIKI                             13
# INRYOGEN-NICHIROKU                  13
# MEIGETSUKI                          12
# GUKANKI                             10
# GIENJUNKO-NIKKI(DAIGO)              10
# DAIGO-ZOJIKI                         9
# KANMON-GYOKI(FUSHIMI)                9
# MOTOHIRO-KOKI                        9
# KEIHAN RAILWAY ADV(ARASHIYAMA)       9
# HANAZONOTENNO-SHINKI                 8
# TERUYOSHI-KOKI                       8
# ZOKU-HONCHOTSUKAN                    8
# TOKITSUGU-KYOKI                      8
# RAI-SANYO-NIPPU                      8
# MANZAIJUNGO-NIKKI(DAIGO)             8
# TAKAGI-ZAICHU-NIKKI                  8
# TOKIYOSHI-KYOKI                      8
# (DAINIHON-SHIRYO)                    7
# GONIJO-MOROMICHIKI                   6
#                                     ..
# MYOHOIN-HINAMIKI [ARASHIYAMA]        1
# EST-from-WF(NIHONGI-RYAKU)           1
# NORITOKI-KYOKI                       1
# KANEKA-KYOKI                         1
# MITAMURA-ENGYO-NIKKI(ARASHIYAMA)     1
# MOROZANE-SHU                         1
# HIRAMATSUKE-NIKKI                    1
# GYOKUSOU                             1
# MITSUTSUNE-SHU                       1
# HANA-NO-SHITABUSHI                   1
# MISININ-KAMPAKUKI                    1
# BURUI-GENYO-WAKASHU                  1
# EST-from-WF(GOHOKOINKI)              1
# EISHOKI                              1
# (DAINIHON-SHIRYO(FUSHIMI))           1
# ZOKU-GOSEN-WAKASHU                   1
# UNONOMONDOKI                         1
# RINEI-WAKASHU                        1
# ITO-JINSAI-NIKKI                     1
# NEWS-PAPET(DAIGO-JI)                 1
# EIGA-MONOGATARI(MATSUNO-SHIDUE)      1
# EIGA-MONOGATARI(MIHATENUYUME)        1
# SHUGAKKAIKI                          1
# KINHISHO                             1
# MICHIIEKO-MARINIKKI                  1
# ASUKAI-SHU                           1
# YANAGIHARA-KOREMITSU-NIKKI           1
# TAKOYAKUSHI-MACHINIKKI               1
# KUJO-TADAMOTO-NIKKI                  1
# SHUI-GUSO                            1
# Name: Reference Name, Length: 222, dtype: int64

# %% [markdown]
# ## Filter the list to only include rows that have a `Full-flowering date (DOY)`

# %%
df[df['Full-flowering date (DOY)'].notnull()]
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11     812                       92.0                401.0          1.0
# 14     815                      105.0                415.0          1.0
# 30     831                       96.0                406.0          1.0
# 50     851                      108.0                418.0          1.0
# 52     853                      104.0                414.0          1.0
# 63     864                      100.0                409.0          1.0
# 65     866                      106.0                416.0          1.0
# 68     869                       95.0                405.0          5.0
# 88     889                      104.0                414.0          5.0
# 90     891                      109.0                419.0          5.0
# 91     892                      108.0                417.0          5.0
# 93     894                      106.0                416.0          5.0
# 94     895                      104.0                414.0          5.0
# 95     896                      104.0                413.0          5.0
# 101    902                      102.0                412.0          5.0
# 107    908                       98.0                407.0          5.0
# 111    912                       95.0                404.0          1.0
# 112    913                      110.0                420.0          5.0
# 116    917                       95.0                405.0          1.0
# 122    923                      104.0                414.0          5.0
# 125    926                       98.0                408.0          1.0
# 129    930                       97.0                407.0          5.0
# 132    933                      106.0                416.0          5.0
# 140    941                      109.0                419.0          1.0
# 148    949                      107.0                417.0          1.0
# 149    950                       95.0                405.0          4.0
# 154    955                       89.0                330.0          5.0
# 156    957                      112.0                422.0          1.0
# 157    958                      109.0                419.0          1.0
# 158    959                       97.0                407.0          3.0
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code              Reference Name
# 11               2.0                  NIHON-KOKI
# 14               2.0                  NIHON-KOKI
# 30               2.0                  NIHON-KOKI
# 50               2.0      MONTOKUTENNO-JITSUROKU
# 52               2.0      MONTOKUTENNO-JITSUROKU
# 63               2.0     NIPPON-SANDAI-JITSUROKU
# 65               2.0     NIPPON-SANDAI-JITSUROKU
# 68               2.0                KANKE-BUNSOU
# 88               2.0     NIPPON-SANDAI-JITSUROKU
# 90               4.0                NIHONKIRYAKU
# 91               3.0         FUSHIMIIN-GOKIROKKU
# 93               2.0                KANKE-BUNSOU
# 94               4.0                NIHONKIRYAKU
# 95               4.0     NIPPON-SANDAI-JITSUROKU
# 101              8.0  EST-from-WF(NIHONGI-RYAKU)
# 107              8.0   EST-from-WF(KIMITADA-SHU)
# 111              2.0                 SHINGISHIKI
# 112              2.0                SHUI-WAKASHU
# 116              2.0                    KINHISHO
# 122              4.0          ZOKU-KOKIN-WAKASHU
# 125              2.0                NIHONKIRYAKU
# 129              8.0   EST-from-WF(SHIRYO-SORAN)
# 132              8.0   EST-from-WF(SHIRYO-SORAN)
# 140              2.0                NIHONKIRYAKU
# 148              2.0                NIHONKIRYAKU
# 149              2.0             DAINIHON-SHIRYO
# 154              4.0                     SHUISHO
# 156              2.0                NIHONKIRYAKU
# 157              2.0                NIHONKIRYAKU
# 158              2.0                     KYUREKI
# ...              ...                         ...
# 1185             0.0      NEWS-PAPER(ARASHIYAMA)
# 1186             0.0      NEWS-PAPER(ARASHIYAMA)
# 1187             0.0      NEWS-PAPER(ARASHIYAMA)
# 1188             0.0      NEWS-PAPER(ARASHIYAMA)
# 1189             0.0      NEWS-PAPER(ARASHIYAMA)
# 1190             0.0      NEWS-PAPER(ARASHIYAMA)
# 1191             0.0      NEWS-PAPER(ARASHIYAMA)
# 1192             0.0      NEWS-PAPER(ARASHIYAMA)
# 1193             0.0      NEWS-PAPER(ARASHIYAMA)
# 1194             0.0      NEWS-PAPER(ARASHIYAMA)
# 1195             0.0      NEWS-PAPER(ARASHIYAMA)
# 1196             0.0      NEWS-PAPER(ARASHIYAMA)
# 1197             0.0      NEWS-PAPER(ARASHIYAMA)
# 1198             0.0      NEWS-PAPER(ARASHIYAMA)
# 1199             0.0      NEWS-PAPER(ARASHIYAMA)
# 1200             0.0      NEWS-PAPER(ARASHIYAMA)
# 1201             0.0      NEWS-PAPER(ARASHIYAMA)
# 1202             0.0      NEWS-PAPER(ARASHIYAMA)
# 1203             0.0      NEWS-PAPER(ARASHIYAMA)
# 1204             0.0      NEWS-PAPER(ARASHIYAMA)
# 1205             0.0      NEWS-PAPER(ARASHIYAMA)
# 1206             0.0      NEWS-PAPER(ARASHIYAMA)
# 1207             0.0      NEWS-PAPER(ARASHIYAMA)
# 1208             0.0      NEWS-PAPER(ARASHIYAMA)
# 1209             0.0      NEWS-PAPER(ARASHIYAMA)
# 1210             0.0      NEWS-PAPER(ARASHIYAMA)
# 1211             0.0      NEWS-PAPER(ARASHIYAMA)
# 1212             0.0      NEWS-PAPER(ARASHIYAMA)
# 1213             0.0      NEWS-PAPER(ARASHIYAMA)
# 1214             0.0      NEWS-PAPER(ARASHIYAMA)
#
# [827 rows x 6 columns]

# %% [markdown]
# ## Make a histogram of the full-flowering date.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['Full-flowering date (DOY)'].value_counts().plot(kind = 'barh')

# %% [markdown]
# ## Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df['Full-flowering date (DOY)'].hist(bins=39)

# %% [markdown]
# ## What's the average number of days it takes for the flowers to blossom? The max? Min? And how many records do we have?
#
# Answer these with one line of code.

# %%
df['Full-flowering date (DOY)'].describe()
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: Full-flowering date (DOY), dtype: float64

# %% [markdown]
# ## What's the average number of days into the year cherry flowers normally blossomed before 1900?

# %%
df[df['AD'].astype(float) < 1900].mean()
# Out:
# AD                           1350.000000
# Full-flowering date (DOY)     105.207283
# Full-flowering date           414.389356
# Source code                     3.341737
# Data type code                  2.009804
# dtype: float64

# %% [markdown]
# ## How about after 1900?

# %%
df[df['AD'].astype(float) > 1900].mean()
# Out:
# AD                           1958.000000
# Full-flowering date (DOY)     100.312500
# Full-flowering date           409.446429
# Source code                     3.964286
# Data type code                  0.000000
# dtype: float64

# %% [markdown]
# ## How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
df['Data type code'].value_counts()
# Out:
# 2.0    454
# 1.0    166
# 0.0    124
# 4.0     39
# 3.0     30
# 8.0     11
# 9.0      3
# Name: Data type code, dtype: int64

# %% [markdown]
# ## Actually, that looks terrible. Replace the "Source code" and "data type code" columns with the values they stand for.

# %%
replacements = {
  1: 'Reported by Taguchi (1939), J. Marine Meteorol. Soc. (Umi to Sora), 19, 217-227',
  2: 'Added by Sekiguchi (1969), Tokyo Geography Papers, 13, 175-190',
  3: 'Added by Aono and Omoto (1994), J. Agric. Meteorol., 49, 263-272',
  4: 'Added by Aono and Kazui (2008), Int. J. Climatol., 28, 905-914 (doi: 10.1002/joc.1594)',
  5: 'Cherry phenological data, Added by Aono and Saito (2010), Int. J. Biometeorol., 54, 211-219',
  6: 'Added by Aono (2011), Time Studies, 4, 17-29. (in Japanese with English abstract)',
  7: 'Added by Aono (2012), Chikyu Kankyo, 17, 21-29. (in Japanese)',
  8: 'Found after the last publication of articles'  
}
df['Source code'].replace(replacements, inplace=True)
df.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                       99.0                409.0
# 1211  2012                      101.0                410.0
# 1212  2013                       93.0                403.0
# 1213  2014                       94.0                404.0
# 1214  2015                       93.0                403.0
#
#                                        Source code  Data type code  \
# 1210  Found after the last publication of articles             0.0
# 1211  Found after the last publication of articles             0.0
# 1212  Found after the last publication of articles             0.0
# 1213  Found after the last publication of articles             0.0
# 1214  Found after the last publication of articles             0.0
#
#               Reference Name
# 1210  NEWS-PAPER(ARASHIYAMA)
# 1211  NEWS-PAPER(ARASHIYAMA)
# 1212  NEWS-PAPER(ARASHIYAMA)
# 1213  NEWS-PAPER(ARASHIYAMA)
# 1214  NEWS-PAPER(ARASHIYAMA)

# %%
replacements = {
  0: 'data from modern times (full-bloom date since 1880s)',
  1: 'from diary description about full-bloom',
  2: 'from diary description about cherry blossom viewing party',
  3: 'from diary description about presents of cherry twigs from party participants',
  4: 'title in Japanese poety',
  8: 'Deduced from wisteria phenology, using the relation proposed by Aono and Saito (2010)',
  9: 'Deduced from Japanese kerria phenology, using the relation proposed by Aono (2011)'  
}
df['Data type code'].replace(replacements, inplace=True)
df.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                       99.0                409.0
# 1211  2012                      101.0                410.0
# 1212  2013                       93.0                403.0
# 1213  2014                       94.0                404.0
# 1214  2015                       93.0                403.0
#
#                                        Source code  \
# 1210  Found after the last publication of articles
# 1211  Found after the last publication of articles
# 1212  Found after the last publication of articles
# 1213  Found after the last publication of articles
# 1214  Found after the last publication of articles
#
#                                          Data type code  \
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name
# 1210  NEWS-PAPER(ARASHIYAMA)
# 1211  NEWS-PAPER(ARASHIYAMA)
# 1212  NEWS-PAPER(ARASHIYAMA)
# 1213  NEWS-PAPER(ARASHIYAMA)
# 1214  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## Show only the years where our data was from a title in Japanese poetry

# %%
df[df['Data type code'] =='title in Japanese poety']
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 90     891                      109.0                419.0
# 94     895                      104.0                414.0
# 95     896                      104.0                413.0
# 122    923                      104.0                414.0
# 154    955                       89.0                330.0
# 168    969                       98.0                408.0
# 206   1007                      106.0                416.0
# 232   1033                      102.0                412.0
# 235   1036                      104.0                413.0
# 259   1060                      108.0                417.0
# 260   1061                       92.0                402.0
# 283   1084                      120.0                429.0
# 294   1095                      100.0                410.0
# 381   1182                      104.0                414.0
# 389   1190                      112.0                422.0
# 400   1201                       96.0                406.0
# 415   1216                      101.0                410.0
# 418   1219                      101.0                411.0
# 420   1221                       99.0                409.0
# 422   1223                      116.0                426.0
# 435   1236                       87.0                327.0
# 464   1265                       98.0                408.0
# 467   1268                      103.0                412.0
# 468   1269                      100.0                410.0
# 470   1271                      100.0                410.0
# 488   1289                      107.0                417.0
# 500   1301                       95.0                405.0
# 523   1324                       98.0                407.0
# 529   1330                      108.0                418.0
# 646   1447                      111.0                421.0
# 652   1453                      107.0                417.0
# 653   1454                      105.0                415.0
# 673   1474                       98.0                408.0
# 733   1534                      108.0                418.0
# 791   1592                       98.0                407.0
# 839   1640                      103.0                412.0
# 860   1661                       93.0                403.0
# 1045  1846                       98.0                408.0
# 1062  1863                      118.0                428.0
#
#                                             Source code  \
# 90    Cherry phenological data, Added by Aono and Sa...
# 94    Cherry phenological data, Added by Aono and Sa...
# 95    Cherry phenological data, Added by Aono and Sa...
# 122   Cherry phenological data, Added by Aono and Sa...
# 154   Cherry phenological data, Added by Aono and Sa...
# 168   Cherry phenological data, Added by Aono and Sa...
# 206   Cherry phenological data, Added by Aono and Sa...
# 232   Cherry phenological data, Added by Aono and Sa...
# 235   Cherry phenological data, Added by Aono and Sa...
# 259   Cherry phenological data, Added by Aono and Sa...
# 260   Added by Aono (2011), Time Studies, 4, 17-29. ...
# 283   Cherry phenological data, Added by Aono and Sa...
# 294   Cherry phenological data, Added by Aono and Sa...
# 381   Added by Aono (2011), Time Studies, 4, 17-29. ...
# 389   Cherry phenological data, Added by Aono and Sa...
# 400   Cherry phenological data, Added by Aono and Sa...
# 415   Cherry phenological data, Added by Aono and Sa...
# 418   Cherry phenological data, Added by Aono and Sa...
# 420   Cherry phenological data, Added by Aono and Sa...
# 422   Cherry phenological data, Added by Aono and Sa...
# 435   Added by Aono (2012), Chikyu Kankyo, 17, 21-29...
# 464   Added by Aono (2011), Time Studies, 4, 17-29. ...
# 467   Added by Aono (2011), Time Studies, 4, 17-29. ...
# 468   Added by Aono and Omoto (1994), J. Agric. Mete...
# 470   Cherry phenological data, Added by Aono and Sa...
# 488   Added by Aono and Omoto (1994), J. Agric. Mete...
# 500   Added by Aono and Kazui (2008), Int. J. Climat...
# 523   Cherry phenological data, Added by Aono and Sa...
# 529   Added by Aono (2012), Chikyu Kankyo, 17, 21-29...
# 646   Added by Aono and Omoto (1994), J. Agric. Mete...
# 652   Added by Aono and Omoto (1994), J. Agric. Mete...
# 653   Added by Aono and Omoto (1994), J. Agric. Mete...
# 673   Added by Aono and Omoto (1994), J. Agric. Mete...
# 733   Added by Aono and Omoto (1994), J. Agric. Mete...
# 791   Added by Aono and Kazui (2008), Int. J. Climat...
# 839   Added by Aono and Omoto (1994), J. Agric. Mete...
# 860   Added by Aono (2012), Chikyu Kankyo, 17, 21-29...
# 1045  Added by Aono and Kazui (2008), Int. J. Climat...
# 1062  Added by Aono and Kazui (2008), Int. J. Climat...
#
#                Data type code              Reference Name
# 90    title in Japanese poety                NIHONKIRYAKU
# 94    title in Japanese poety                NIHONKIRYAKU
# 95    title in Japanese poety     NIPPON-SANDAI-JITSUROKU
# 122   title in Japanese poety          ZOKU-KOKIN-WAKASHU
# 154   title in Japanese poety                     SHUISHO
# 168   title in Japanese poety                NIHONKIRYAKU
# 206   title in Japanese poety              MIDO-KAMPAKUKI
# 232   title in Japanese poety                NIHONKIRYAKU
# 235   title in Japanese poety                NIHONKIRYAKU
# 259   title in Japanese poety         SHIN-SENZAI-WAKASHU
# 260   title in Japanese poety                MOROZANE-SHU
# 283   title in Japanese poety          ZOKU-GOSEN-WAKASHU
# 294   title in Japanese poety                     CHUYUKI
# 381   title in Japanese poety  TSUKIMOUDE-WAKASHU(PART-3)
# 389   title in Japanese poety                SHUGYOKU-SHU
# 400   title in Japanese poety           INOKUMA-KAMPAKUKI
# 415   title in Japanese poety            JUNTOKUIN-GYOSHU
# 418   title in Japanese poety            JUNTOKUIN-GYOSHU
# 420   title in Japanese poety                   SHUI-GUSO
# 422   title in Japanese poety              MITSUTSUNE-SHU
# 435   title in Japanese poety              SHIIBA-WAKASHU
# 464   title in Japanese poety                  TAMEIE-SHU
# 467   title in Japanese poety                  TAMEIE-SHU
# 468   title in Japanese poety               ZOKU-SHIGUSHO
# 470   title in Japanese poety         DAINAGON-TAMEIE-SHU
# 488   title in Japanese poety         NAKANOTSUKASA-NIKKI
# 500   title in Japanese poety                SANEMI-KYOKI
# 523   title in Japanese poety        HANAZONOTENNO-SHINKI
# 529   title in Japanese poety               RINEI-WAKASHU
# 646   title in Japanese poety                    SOKONSHU
# 652   title in Japanese poety                    SOKONSHU
# 653   title in Japanese poety                    SOKONSHU
# 673   title in Japanese poety              ENROKUCHOKASHU
# 733   title in Japanese poety      GONARAIN-GYOSEI-BASSHO
# 791   title in Japanese poety             TOKITSUNE-KYOKI
# 839   title in Japanese poety                  KYOHAKUSHU
# 860   title in Japanese poety         BURUI-GENYO-WAKASHU
# 1045  title in Japanese poety                  TEIEN-EISO
# 1062  title in Japanese poety                  YATAKA-SHU

# %% [markdown]
# ## Graph the full-flowering date (DOY) over time

# %%
df['Full-flowering date (DOY)'].hist()

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
df.rolling(10, on='AD', min_periods=5).mean().tail()
# If this gives you an error you're using an old pandas version,
# so you can use df.set_index('AD').rolling(10, min_periods=5).mean().reset_index().tail()
# instead
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                       95.9                405.7
# 1211  2012                       96.9                406.6
# 1212  2013                       96.4                406.1
# 1213  2014                       96.6                406.4
# 1214  2015                       96.0                405.8
#
#                                        Source code  \
# 1210  Found after the last publication of articles
# 1211  Found after the last publication of articles
# 1212  Found after the last publication of articles
# 1213  Found after the last publication of articles
# 1214  Found after the last publication of articles
#
#                                          Data type code  \
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name
# 1210  NEWS-PAPER(ARASHIYAMA)
# 1211  NEWS-PAPER(ARASHIYAMA)
# 1212  NEWS-PAPER(ARASHIYAMA)
# 1213  NEWS-PAPER(ARASHIYAMA)
# 1214  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# Adjust the code above to compute **and graph** a 20-year rolling average for the entire dataset.

# %%
df.rolling(20, on='AD', min_periods=5).mean()['Full-flowering date (DOY)'].plot()

# %% [markdown]
# # Adding a month column
#
# ### HOLD ON, time to learn something
#
# **There are a few ways to do the next question**, but a couple popular methods will have pandas yell at you. You might want to try this new thing called `loc`! **It is used to update a column in a row based on a condition.**
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `df.country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.
#
# ### Actually adding our column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.

# %%
df.loc[df['Full-flowering date'] < 400, 'month'] = 'March'

# %%
df.loc[df['Full-flowering date'] > 400, 'month'] = 'April'

# %%
df.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                       99.0                409.0
# 1211  2012                      101.0                410.0
# 1212  2013                       93.0                403.0
# 1213  2014                       94.0                404.0
# 1214  2015                       93.0                403.0
#
#                                        Source code  \
# 1210  Found after the last publication of articles
# 1211  Found after the last publication of articles
# 1212  Found after the last publication of articles
# 1213  Found after the last publication of articles
# 1214  Found after the last publication of articles
#
#                                          Data type code  \
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name  month
# 1210  NEWS-PAPER(ARASHIYAMA)  April
# 1211  NEWS-PAPER(ARASHIYAMA)  April
# 1212  NEWS-PAPER(ARASHIYAMA)  April
# 1213  NEWS-PAPER(ARASHIYAMA)  April
# 1214  NEWS-PAPER(ARASHIYAMA)  April

# %% [markdown]
# ### Using your new column, how many blossomings happened in each month?

# %%
df['month'].value_counts()
# Out:
# April    817
# March     10
# Name: month, dtype: int64

# %% [markdown]
# ### Graph how many blossomings happened in each month.

# %%
df['month'].value_counts().plot(kind = 'barh')

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called **day-of-month** based on the full-flowering date.
#
# - 402 means "April 2"
# - 312 means "March 12"
# - 511 means "May 11"
#
# **We're only interested in the second part**. Previously I've had students convert them to integers to do this, but you know regular expressions!
#
# - Tip: You won't be able to extract anything from a float, you'll need it to be a string
# - Tip: There are two things that mean "talk about this column as a string," maybe you want me to talk about them?

# %%
df['day-of-month'] = df['Full-flowering date'].astype(str).str.extract('\d(\d\d)', expand = False)
df.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                       99.0                409.0
# 1211  2012                      101.0                410.0
# 1212  2013                       93.0                403.0
# 1213  2014                       94.0                404.0
# 1214  2015                       93.0                403.0
#
#                                        Source code  \
# 1210  Found after the last publication of articles
# 1211  Found after the last publication of articles
# 1212  Found after the last publication of articles
# 1213  Found after the last publication of articles
# 1214  Found after the last publication of articles
#
#                                          Data type code  \
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name  month day-of-month
# 1210  NEWS-PAPER(ARASHIYAMA)  April           09
# 1211  NEWS-PAPER(ARASHIYAMA)  April           10
# 1212  NEWS-PAPER(ARASHIYAMA)  April           03
# 1213  NEWS-PAPER(ARASHIYAMA)  April           04
# 1214  NEWS-PAPER(ARASHIYAMA)  April           03

# %% [markdown]
# Now that you've successfully extracted the last two letters, save them into a new column called `'day-of-month'`

# %% [markdown]
# ### 20. Adding a date column
#
# Now take the `'month'` and `'day-of-month'` columns and combine them in order to create a new column called `'date'`. If should look like "April 09".

# %%
df['date'] = df.month.str.cat(df['day-of-month'])
df.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                       99.0                409.0
# 1211  2012                      101.0                410.0
# 1212  2013                       93.0                403.0
# 1213  2014                       94.0                404.0
# 1214  2015                       93.0                403.0
#
#                                        Source code  \
# 1210  Found after the last publication of articles
# 1211  Found after the last publication of articles
# 1212  Found after the last publication of articles
# 1213  Found after the last publication of articles
# 1214  Found after the last publication of articles
#
#                                          Data type code  \
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name  month day-of-month     date
# 1210  NEWS-PAPER(ARASHIYAMA)  April           09  April09
# 1211  NEWS-PAPER(ARASHIYAMA)  April           10  April10
# 1212  NEWS-PAPER(ARASHIYAMA)  April           03  April03
# 1213  NEWS-PAPER(ARASHIYAMA)  April           04  April04
# 1214  NEWS-PAPER(ARASHIYAMA)  April           03  April03
